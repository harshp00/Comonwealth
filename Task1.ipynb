# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeClassifier, DecisionTreeRegressor

# %%
df = pd.read_excel("Cookies.xlsx")

# %%
df.head()
# Out:
#    Customer ID  Age Age Group  Postcode Gender Favourite Cookie  \
# 0         1001   60     60-69      2000      M        Choc chip
# 1         1002   53     50-59      2010      M        Choc chip
# 2         1003   22     20-29      2010      F        Choc chip
# 3         1004   30     30-39      2010      F        Choc chip
# 4         1005   52     50-59      2010      F        Macadamia
#
#    Cookies bought each week
# 0                         1
# 1                         1
# 2                         2
# 3                         6
# 4                         3

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 46 entries, 0 to 45
# Data columns (total 7 columns):
# Customer ID                 46 non-null int64
# Age                         46 non-null int64
# Age Group                   46 non-null object
# Postcode                    46 non-null int64
# Gender                      46 non-null object
# Favourite Cookie            46 non-null object
# Cookies bought each week    46 non-null int64
# dtypes: int64(4), object(3)
# memory usage: 2.6+ KB

# %%
df.describe()
# Out:
#        Customer ID        Age     Postcode  Cookies bought each week
# count    46.000000  46.000000    46.000000                 46.000000
# mean   1023.500000  34.173913  2136.217391                  3.978261
# std      13.422618  16.189577   204.315433                  3.666601
# min    1001.000000  12.000000  2000.000000                  1.000000
# 25%    1012.250000  20.250000  2000.000000                  1.250000
# 50%    1023.500000  31.500000  2014.500000                  3.000000
# 75%    1034.750000  44.750000  2296.250000                  5.750000
# max    1046.000000  68.000000  2873.000000                 20.000000

# %%
df.columns
# Out:
# Index(['Customer ID', 'Age', 'Age Group', 'Postcode', 'Gender',
#        'Favourite Cookie', 'Cookies bought each week'],
#       dtype='object')

# %%
df['Favourite Cookie'].value_counts()
# Out:
# Macadamia         16
# Choc chip         12
# Granola            6
# Triple choc        6
# Mint               4
# Salted caramel     2
# Name: Favourite Cookie, dtype: int64

# %%
df['Postcode'].value_counts()
# Out:
# 2000    17
# 2010     5
# 2022     3
# 2321     3
# 2093     2
# 2210     2
# 2331     2
# 2873     1
# 2222     1
# 2019     1
# 2763     1
# 2444     1
# 2332     1
# 2030     1
# 2333     1
# 2211     1
# 2344     1
# 2347     1
# 2001     1
# Name: Postcode, dtype: int64

# %%
df.corr()
# Out:
#                           Customer ID       Age  Postcode  \
# Customer ID                  1.000000 -0.347998  0.302106
# Age                         -0.347998  1.000000 -0.395040
# Postcode                     0.302106 -0.395040  1.000000
# Cookies bought each week     0.072019 -0.203586  0.196171
#
#                           Cookies bought each week
# Customer ID                               0.072019
# Age                                      -0.203586
# Postcode                                  0.196171
# Cookies bought each week                  1.000000

# %%
sns.heatmap(df.corr())

# %%
sns.countplot('Gender',data=df)

# %%
sns.barplot(x='Gender',y='Cookies bought each week',data=df)

# %%
sns.barplot(x='Age Group',y='Cookies bought each week',data=df)

# %%
sns.countplot('Favourite Cookie',data=df)

# %%
plt.figure(figsize=(20,5))
sns.countplot('Postcode',data=df)

# %%
sns.barplot(x='Favourite Cookie',y='Age',data=df)
